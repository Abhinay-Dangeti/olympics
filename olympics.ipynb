# %% [markdown]
# ### Introduction

# %% [markdown]
# In the below project , I am analysing the olympic dataset which contains the details of people who won medals in olympics from 2000 to 2012.It also contains the category of sports they won medals and the date on which they have won medals.

# %% [markdown]
# ### Varaibles in the Dataset

# %% [markdown]
# |variable name|variable explanation|
# |-------------|--------------------|
# |name|Name of the person who won medal in olympics|
# |age|contains the age of the person|
# |country|contains the country of the person who won medal|
# |year|contains the year on which he won the medal|
# |sports| contains the category of sports on which he won the medal|
# |gold medal|contains the total medals won by each person|
# |silver medal|contains the silver medals won by each person|
# |brone medal|contains the bronze medal won by each person|
# |total medal|contains the total medals won by each person|
# |Date|contains the Date of person on which he won the medal|

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno
# importing the essential libraries that would be essential in completing the project

# %%
olympic=pd.read_csv(r"C:\Users\dsv24\Downloads\olympix_data_organized_with_header (1).csv")
# the dateset is in the csv format so we read it as read_csv to access the file in the dataframe.

# %%
olympic
# Out:
#                       name   age        country  year  Date_Given      sports  \
# 0           Michael Phelps  23.0  United States  2008   8/24/2008    Swimming
# 1           Michael Phelps  19.0  United States  2004   8/29/2004    Swimming
# 2           Michael Phelps  27.0  United States  2012  08-12-2012    Swimming
# 3         Natalie Coughlin  25.0  United States  2008   8/24/2008    Swimming
# 4            Aleksey Nemov  24.0         Russia  2000  10-01-2000  Gymnastics
# ...                    ...   ...            ...   ...         ...         ...
# 8613      Olena Sadovnycha  32.0        Ukraine  2000  10-01-2000     Archery
# 8614      Kateryna Serdiuk  17.0        Ukraine  2000  10-01-2000     Archery
# 8615      Wietse van Alten  21.0    Netherlands  2000  10-01-2000     Archery
# 8616  Sandra Wagner-Sachse  31.0        Germany  2000  10-01-2000     Archery
# 8617             Rod White  23.0  United States  2000  10-01-2000     Archery
#
# ...

# %%
olympic.shape
# shape gives us the dimensions of the table in rows and columns
# Out:
# (8618, 10)

# %%
olympic.size 
# size gives us the product of rows and columns.
# Out:
# 86180

# %%
olympic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8618 entries, 0 to 8617
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          8613 non-null   object
#  1   age           8613 non-null   float64
#  2   country       8618 non-null   object
#  3   year          8618 non-null   int64
#  4   Date_Given    8618 non-null   object
#  5   sports        8618 non-null   object
#  6   gold_medal    8618 non-null   int64
#  7   silver_medal  8618 non-null   int64
#  8   brone_medal   8618 non-null   int64
#  9   total_medal   8618 non-null   int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 673.4+ KB

# %%
olympic.describe(include="all")
# describe funciton gives us the statistical measures of the numerial variables
# Out:
#               name          age        country         year Date_Given  \
# count         8613  8613.000000           8618  8618.000000       8618
# unique        6955          NaN            110          NaN          7
# top     Matt Wells          NaN  United States          NaN  8/24/2008
# freq             4          NaN           1109          NaN       1872
# mean           NaN    26.405434            NaN  2005.978881        NaN
# std            NaN     5.102118            NaN     4.289946        NaN
# min            NaN    15.000000            NaN  2000.000000        NaN
# 25%            NaN    23.000000            NaN  2002.000000        NaN
# 50%            NaN    26.000000            NaN  2006.000000        NaN
# 75%            NaN    29.000000            NaN  2010.000000        NaN
# max            NaN    61.000000            NaN  2012.000000        NaN
#
#            sports   gold_medal  silver_medal  brone_medal  total_medal
# ...

# %%
msno.bar(olympic)
# msno library is useful to see if there is any missing data present in the table.
# Out:
# <AxesSubplot:>

# %%
olympic.nunique()
# nunqiue gives us the number of unique values present in each column.
# Out:
# name            6955
# age               42
# country          110
# year               7
# Date_Given         7
# sports            49
# gold_medal         7
# silver_medal       4
# brone_medal        4
# total_medal        7
# dtype: int64

# %%
olympic['Date']=pd.to_datetime(olympic['Date_Given'])
# changing the datatype of Date_Given to Datetime64.

# %%
olympic.info()
# it gives us the information about the table.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8618 entries, 0 to 8617
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          8613 non-null   object
#  1   age           8613 non-null   float64
#  2   country       8618 non-null   object
#  3   year          8618 non-null   int64
#  4   Date_Given    8618 non-null   object
#  5   sports        8618 non-null   object
#  6   gold_medal    8618 non-null   int64
#  7   silver_medal  8618 non-null   int64
#  8   brone_medal   8618 non-null   int64
#  9   total_medal   8618 non-null   int64
#  10  Date          8618 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(5), object(4)
# memory usage: 740.7+ KB

# %%
olympic.head()
# Out:
#                name   age        country  year  Date_Given      sports  \
# 0    Michael Phelps  23.0  United States  2008   8/24/2008    Swimming
# 1    Michael Phelps  19.0  United States  2004   8/29/2004    Swimming
# 2    Michael Phelps  27.0  United States  2012  08-12-2012    Swimming
# 3  Natalie Coughlin  25.0  United States  2008   8/24/2008    Swimming
# 4     Aleksey Nemov  24.0         Russia  2000  10-01-2000  Gymnastics
#
#    gold_medal  silver_medal  brone_medal  total_medal       Date
# 0           8             0            0            8 2008-08-24
# 1           6             0            2            8 2004-08-29
# 2           4             2            0            6 2012-08-12
# 3           1             2            3            6 2008-08-24
# 4           2             1            3            6 2000-10-01

# %%
olympic.tail()
# Out:
#                       name   age        country  year  Date_Given   sports  \
# 8613      Olena Sadovnycha  32.0        Ukraine  2000  10-01-2000  Archery
# 8614      Kateryna Serdiuk  17.0        Ukraine  2000  10-01-2000  Archery
# 8615      Wietse van Alten  21.0    Netherlands  2000  10-01-2000  Archery
# 8616  Sandra Wagner-Sachse  31.0        Germany  2000  10-01-2000  Archery
# 8617             Rod White  23.0  United States  2000  10-01-2000  Archery
#
#       gold_medal  silver_medal  brone_medal  total_medal       Date
# 8613           0             1            0            1 2000-10-01
# 8614           0             1            0            1 2000-10-01
# 8615           0             0            1            1 2000-10-01
# 8616           0             0            1            1 2000-10-01
# 8617           0             0            1            1 2000-10-01

# %%
olympic[['name','country','sports']]=olympic[['name','country','sports']].astype('category')

# %%
olympic.info() 
# from the below we can see the updated Dtype with category.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8618 entries, 0 to 8617
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          8613 non-null   category
#  1   age           8613 non-null   float64
#  2   country       8618 non-null   category
#  3   year          8618 non-null   int64
#  4   Date_Given    8618 non-null   object
#  5   sports        8618 non-null   category
#  6   gold_medal    8618 non-null   int64
#  7   silver_medal  8618 non-null   int64
#  8   brone_medal   8618 non-null   int64
#  9   total_medal   8618 non-null   int64
#  10  Date          8618 non-null   datetime64[ns]
# dtypes: category(3), datetime64[ns](1), float64(1), int64(5), object(1)
# memory usage: 891.1+ KB

# %%
olympic.drop(['Date_Given'],axis=1,inplace=True) 
# Droping the Date_given column as we already created a Date column from it with data type datetime64[ns].

# %%
olympic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8618 entries, 0 to 8617
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          8613 non-null   category
#  1   age           8613 non-null   float64
#  2   country       8618 non-null   category
#  3   year          8618 non-null   int64
#  4   sports        8618 non-null   category
#  5   gold_medal    8618 non-null   int64
#  6   silver_medal  8618 non-null   int64
#  7   brone_medal   8618 non-null   int64
#  8   total_medal   8618 non-null   int64
#  9   Date          8618 non-null   datetime64[ns]
# dtypes: category(3), datetime64[ns](1), float64(1), int64(5)
# memory usage: 823.8 KB

# %%
olympic[olympic.duplicated()]
# Out:
#      name  age    country  year      sports  gold_medal  silver_medal  \
# 1429  NaN  NaN     Brazil  2012  Volleyball           0             1
# 1430  NaN  NaN     Brazil  2012  Volleyball           0             1
# 4486  NaN  NaN  Argentina  2012      Hockey           0             1
#
#       brone_medal  total_medal       Date
# 1429            0            1 2012-08-12
# 1430            0            1 2012-08-12
# 4486            0            1 2012-08-12

# %%
olympic.duplicated().sum()
# there are 3 duplicate values present in the data set
# Out:
# 3

# %%
olympic.drop_duplicates(inplace=True)
# with the help of drop_duplicated function we have removed the duplicated values in the dataset.

# %%
olympic.duplicated().sum()
# now we can see there are no duplicated values present in the dataset
# Out:
# 0

# %%
olympic[olympic['name'].isnull()]
# Out:
#      name  age    country  year      sports  gold_medal  silver_medal  \
# 1428  NaN  NaN     Brazil  2012  Volleyball           0             1
# 4485  NaN  NaN  Argentina  2012      Hockey           0             1
#
#       brone_medal  total_medal       Date
# 1428            0            1 2012-08-12
# 4485            0            1 2012-08-12

# %%
olympic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8615 entries, 0 to 8617
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          8613 non-null   category
#  1   age           8613 non-null   float64
#  2   country       8615 non-null   category
#  3   year          8615 non-null   int64
#  4   sports        8615 non-null   category
#  5   gold_medal    8615 non-null   int64
#  6   silver_medal  8615 non-null   int64
#  7   brone_medal   8615 non-null   int64
#  8   total_medal   8615 non-null   int64
#  9   Date          8615 non-null   datetime64[ns]
# dtypes: category(3), datetime64[ns](1), float64(1), int64(5)
# memory usage: 890.8 KB

# %%
olympic.isnull().value_counts(normalize=True)*100
# Out:
# name   age    country  year   sports  gold_medal  silver_medal  brone_medal  total_medal  Date
# False  False  False    False  False   False       False         False        False        False    100.0
# dtype: float64

# %%
olympic.dropna(inplace=True) # i am removing the null values from the table as they are only 2 null values.

# %%
olympic.isnull().sum()  # we can see here that there are no null values present.
# Out:
# name            0
# age             0
# country         0
# year            0
# sports          0
# gold_medal      0
# silver_medal    0
# brone_medal     0
# total_medal     0
# Date            0
# dtype: int64

# %%
numerical = olympic.select_dtypes('number') # storing all the numerical columns in "numerical"
category=olympic.select_dtypes("category") # storing all the category columns in "category"

# %%
numerical
# Out:
#        age  year  gold_medal  silver_medal  brone_medal  total_medal
# 0     23.0  2008           8             0            0            8
# 1     19.0  2004           6             0            2            8
# 2     27.0  2012           4             2            0            6
# 3     25.0  2008           1             2            3            6
# 4     24.0  2000           2             1            3            6
# ...    ...   ...         ...           ...          ...          ...
# 8613  32.0  2000           0             1            0            1
# 8614  17.0  2000           0             1            0            1
# 8615  21.0  2000           0             0            1            1
# 8616  31.0  2000           0             0            1            1
# 8617  23.0  2000           0             0            1            1
#
# [8613 rows x 6 columns]

# %%
category
# Out:
#                       name        country      sports
# 0           Michael Phelps  United States    Swimming
# 1           Michael Phelps  United States    Swimming
# 2           Michael Phelps  United States    Swimming
# 3         Natalie Coughlin  United States    Swimming
# 4            Aleksey Nemov         Russia  Gymnastics
# ...                    ...            ...         ...
# 8613      Olena Sadovnycha        Ukraine     Archery
# 8614      Kateryna Serdiuk        Ukraine     Archery
# 8615      Wietse van Alten    Netherlands     Archery
# 8616  Sandra Wagner-Sachse        Germany     Archery
# 8617             Rod White  United States     Archery
#
# [8613 rows x 3 columns]

# %% [markdown]
# ### Please remove special characters from the name column.

# %%
olympic[olympic.name.str.contains("[-]")]
# Out:
#                                name   age      country  year  \
# 17            Libby Lenton-Trickett  23.0    Australia  2008
# 28                      An Hyeon-Su  20.0  South Korea  2006
# 32    Leontien Zijlaard-van Moorsel  30.0  Netherlands  2000
# 86                     Lee Jeong-Su  20.0  South Korea  2010
# 89                      Jin Seon-Yu  17.0  South Korea  2006
# ...                             ...   ...          ...   ...
# 8600                     Yun Mi-Jin  21.0  South Korea  2004
# 8607                   Jang Yong-Ho  24.0  South Korea  2000
# 8609                 Kim Cheong-Tae  20.0  South Korea  2000
# 8611                      O Gyo-Mun  28.0  South Korea  2000
# 8616           Sandra Wagner-Sachse  31.0      Germany  2000
#
#                          sports  gold_medal  silver_medal  brone_medal  \
# 17                     Swimming           2             1            1
# 28    Short-Track Speed Skating           3             0            1
# ...

# %%
olympic["name"]=olympic.name.str.replace('[#,@,&,-]',' ')
# Out:
# C:\Users\dsv24\AppData\Local\Temp/ipykernel_22208/2739723060.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   olympic["name"]=olympic.name.str.replace('[#,@,&,-]',' ')

# %%
olympic.tail()
# Out:
#                       name   age        country  year   sports  gold_medal  \
# 8613      Olena Sadovnycha  32.0        Ukraine  2000  Archery           0
# 8614      Kateryna Serdiuk  17.0        Ukraine  2000  Archery           0
# 8615      Wietse van Alten  21.0    Netherlands  2000  Archery           0
# 8616  Sandra Wagner Sachse  31.0        Germany  2000  Archery           0
# 8617             Rod White  23.0  United States  2000  Archery           0
#
#       silver_medal  brone_medal  total_medal       Date
# 8613             1            0            1 2000-10-01
# 8614             1            0            1 2000-10-01
# 8615             0            1            1 2000-10-01
# 8616             0            1            1 2000-10-01
# 8617             0            1            1 2000-10-01

# %%
olympic.iloc[1622:1630]
# Out:
#                        name   age country  year      sports  gold_medal  \
# 1625              Song Nina  24.0   China  2004  Volleyball           1
# 1626      Irina Tebenikhina  25.0  Russia  2004  Volleyball           0
# 1627           Dulce Téllez  20.0    Cuba  2004  Volleyball           0
# 1628       Sergey Tetyukhin  28.0  Russia  2004  Volleyball           0
# 1629  Yelizaveta Tishchenko  29.0  Russia  2004  Volleyball           0
# 1630           Paolo Tofoli  38.0   Italy  2004  Volleyball           0
# 1631     Konstantin Ushakov  34.0  Russia  2004  Volleyball           0
# 1632         Aleksey Verbov  22.0  Russia  2004  Volleyball           0
#
#       silver_medal  brone_medal  total_medal       Date
# 1625             0            0            1 2004-08-29
# 1626             1            0            1 2004-08-29
# 1627             0            1            1 2004-08-29
# 1628             0            1            1 2004-08-29
# ...

# %%
olympic_csv=olympic.to_csv(r"C:\\Users\\dsv24\\Downloads\\olympic.csv",index=False)
# created a csv file from the pandas file

# %% [markdown]
# ### Analysing the categorical variables

# %%
plt.figure(figsize=(10,20))
sns.countplot(y='country',data=olympic).set(title='Different categories in country')
plt.show()

# %% [markdown]
# #### Inference:From the above count plot we can see the differenct categories of countries present in the olympics

# %%
plt.figure(figsize=(15,15))
olympic[['country']].value_counts().plot(kind="pie",fontsize=10,autopct="%1.2f%%",shadow=False)# used pie chart to see the percentage of senior citizens.
plt.legend(bbox_to_anchor=(1.45, 1),loc='upper right')
plt.title('Percentage of total_medals won by various countries')
plt.show()

# %% [markdown]
# #### Inference:From the above pie chart we can see the percentage of countries in the dataset.

# %%
plt.figure(figsize=(10,20))
sns.countplot(y='sports',data=olympic).set(title='Different categories in sports')
plt.show()

# %%
plt.figure(figsize=(10,15))
olympic[['sports']].value_counts().plot(kind="pie",fontsize=10,autopct="%1.2f%%",shadow=False)# used pie chart to see the percentage of senior citizens.
plt.legend(bbox_to_anchor=(1.45, 1),loc='upper right')
plt.title('Percentage of Senior Citizens')
plt.show()

# %% [markdown]
# ### Inference : From the above pie chart we can see the percentage of different categories of sports present in the dataset.

# %% [markdown]
# ### Analysing the numerical variables

# %%
sns.histplot(x='age',data=olympic,kde=True,bins=40).set(title='Distribution of Age') # used histogram from seaborn library to see the distribution of data.
plt.axvline(x=olympic.age.mean(),color='r',label='mean')  # with the matplotlib.pyplot library using vertical axis line to represent mean
plt.axvline(x=olympic.age.median(),color='g',label='median',ls='--')# with the matplotlib.pyplot library using vertical axis line to represent median
plt.legend()  # Places a legend on the Axes

# %%
olympic['age'].skew()
# Out:
# 0.8590070668484233

# %% [markdown]
# #### Inference: From the above histogram, we can see a long right tail and from the skewness values we can say it is moderately right skewed.

# %%
sns.histplot(x='gold_medal',data=olympic,kde=True,bins=40).set(title='Distribution of gold medals') # used histogram from seaborn library to see the distribution of data.
plt.axvline(x=olympic.gold_medal.mean(),color='r',label='mean')  # with the matplotlib.pyplot library using vertical axis line to represent mean
plt.axvline(x=olympic.gold_medal.median(),color='g',label='median',ls='--')# with the matplotlib.pyplot library using vertical axis line to represent median
plt.legend()  # Places a legend on the Axes

# %%
olympic['gold_medal'].skew()
# Out:
# 1.6391698864631166

# %% [markdown]
# #### Inference: From the above histogram, we can say that it has long right tail and from the skewness values we can say that it is highly right skewed.

# %%
sns.histplot(x='silver_medal',data=olympic,kde=True,bins=40).set(title='Distribution of silver medals') # used histogram from seaborn library to see the distribution of data.
plt.axvline(x=olympic.silver_medal.mean(),color='r',label='mean')  # with the matplotlib.pyplot library using vertical axis line to represent mean
plt.axvline(x=olympic.silver_medal.median(),color='g',label='median',ls='--')# with the matplotlib.pyplot library using vertical axis line to represent median
plt.legend()  # Places a legend on the Axes

# %%
olympic['silver_medal'].skew()
# Out:
# 0.9542147523973815

# %% [markdown]
# #### Inference:From the above histogram,we can see a long right tail and form the skewness value we can say it is moderately right skewed.

# %%
sns.histplot(x='brone_medal',data=olympic,kde=True,bins=40).set(title='Distribution of bronze medals') # used histogram from seaborn library to see the distribution of data.
plt.axvline(x=olympic.brone_medal.mean(),color='r',label='mean')  # with the matplotlib.pyplot library using vertical axis line to represent mean
plt.axvline(x=olympic.brone_medal.median(),color='g',label='median',ls='--')# with the matplotlib.pyplot library using vertical axis line to represent median
plt.legend()  # Places a legend on the Axes

# %%
olympic['brone_medal'].skew()
# Out:
# 0.762453818551508

# %% [markdown]
# #### Inference : From the above histogram, we can see a long right tail and from the skewness value we can say it is moderately right skewed.

# %%
sns.histplot(x='total_medal',data=olympic,kde=True,bins=40).set(title='Distribution of total medals') # used histogram from seaborn library to see the distribution of data.
plt.axvline(x=olympic.total_medal.mean(),color='r',label='mean')  # with the matplotlib.pyplot library using vertical axis line to represent mean
plt.axvline(x=olympic.total_medal.median(),color='g',label='median',ls='--')# with the matplotlib.pyplot library using vertical axis line to represent median
plt.legend()  # Places a legend on the Axes

# %%
olympic['total_medal'].skew()
# Out:
# 5.581632709058624

# %% [markdown]
# #### Inference:From the above histogram, we can see that there is a long right tail present and from the skewness value it is highly right skewed.

# %% [markdown]
# #### Please list the top 10 countries with the gold medal, then top10 countries with the silver medal, then bronze medal and the total medal.

# %%
olympic.groupby('country')['gold_medal'].sum().sort_values(ascending=False).head(10)
# Out:
# country
# United States    552
# Russia           234
# China            234
# Germany          223
# Canada           168
# Australia        163
# Great Britain    124
# South Korea      110
# France           108
# Netherlands      101
# Name: gold_medal, dtype: int64

# %%
olympic.groupby('country')['gold_medal'].sum().sort_values(ascending=False).head(10).plot(kind='bar',color='g').set(ylabel='Total Medals Won',title='top 10 countries with gold medal')
# Out:
# [Text(0, 0.5, 'Total Medals Won'),
#  Text(0.5, 1.0, 'top 10 countries with gold medal')]

# %% [markdown]
# #### Inference:From the above plot we can see that United States is the top country with more gold medal

# %%
olympic.groupby('country')['silver_medal'].sum().sort_values(ascending=False).head(10)
# Out:
# country
# United States    440
# Australia        226
# Russia           221
# Germany          183
# China            156
# Netherlands      135
# Spain            116
# Japan            112
# France           107
# Italy            103
# Name: silver_medal, dtype: int64

# %%
olympic.groupby('country')['silver_medal'].sum().sort_values(ascending=False).head(10).plot(kind='bar',color='g').set(ylabel='Total Medals Won',title='top 10 countries with silver medal')
# Out:
# [Text(0, 0.5, 'Total Medals Won'),
#  Text(0.5, 1.0, 'top 10 countries with silver medal')]

# %% [markdown]
# #### Inference:From the above plot we can see United states is the top country with 440 silver medals.

# %%
olympic.groupby('country')['brone_medal'].sum().sort_values(ascending=False).head(10)
# Out:
# country
# United States    320
# Russia           313
# Germany          223
# Australia        220
# Italy            142
# China            140
# Japan            113
# South Korea      105
# Canada           104
# France           103
# Name: brone_medal, dtype: int64

# %%
olympic.groupby('country')['brone_medal'].sum().sort_values(ascending=False).head(10).plot(kind='bar',color='violet').set(ylabel='Total Medals Won',title='Top 10 countries with Bronze medal')
# Out:
# [Text(0, 0.5, 'Total Medals Won'),
#  Text(0.5, 1.0, 'Top 10 countries with Bronze medal')]

# %% [markdown]
# #### Inference: From the above plot we can see United states is the top country with more Bronze medals .

# %%
olympic.year.unique()
# Out:
# array([2008, 2004, 2012, 2000, 2006, 2010, 2002], dtype=int64)

# %%
B=olympic.groupby(by=["year", "country"]).aggregate({"total_medal":"sum"})

# %%
c=B.pivot_table(index="year", columns="country", values=["total_medal"])

# %%
plt.figure(figsize=(10,8))
c.plot.bar(figsize=(18,6))
plt.show()

# %% [markdown]
# #### Inference: From the above plot we can see the total medals won by each country every year.

# %%
sns.barplot(y='Date',x='total_medal',data=olympic)
# Out:
# <AxesSubplot:xlabel='total_medal', ylabel='Date'>

# %% [markdown]
# #### Inference:From the above plot we can see the total medals won on each date.

# %%
olympic['Date'].nunique()
# Out:
# 7

# %%
olympic.groupby('Date')['total_medal'].sum().sort_values(ascending=False)
# Out:
# Date
# 2008-08-24    2050
# 2000-10-01    2005
# 2004-08-29    2004
# 2012-08-12    1941
# 2006-02-26     526
# 2010-02-28     520
# 2002-02-24     478
# Name: total_medal, dtype: int64

# %%
olympic.groupby('Date')['total_medal'].sum().sort_values(ascending=False).plot(kind='line').set(xlabel='Year',ylabel='total medals won',title='Total no of medals won across various years')
# Out:
# [Text(0.5, 0, 'Year'),
#  Text(0, 0.5, 'total medals won'),
#  Text(0.5, 1.0, 'Total no of medals won across various years')]

# %% [markdown]
# #### Inference :From the above plot we can see the total medals won on each year.

# %%
olympic.groupby('Date')['total_medal'].sum().sort_values(ascending=False).plot(kind='bar').set(ylabel='total medals won',title='Total no of medals won across various Dates')
# Out:
# [Text(0, 0.5, 'total medals won'),
#  Text(0.5, 1.0, 'Total no of medals won across various Dates')]

# %% [markdown]
# #### Inference:From the above plot we can see the date wise total medals won.

# %%
olympic.groupby('country')['total_medal'].sum().sort_values(ascending=False).head(10).plot(kind='bar',color='brown').set(ylabel='Total Medals Won',title='Top 10 countries with more medals')
# Out:
# [Text(0, 0.5, 'Total Medals Won'),
#  Text(0.5, 1.0, 'Top 10 countries with more medals')]

# %% [markdown]
# #### Inference:From the above plot we can see the top 10 countries that won total medals in olympics

# %%
olympic.groupby('year')['total_medal'].sum().sort_values(ascending=False).head(10).to_frame().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# #### Inference:From the above plot we can see total medals won on each year.

# %%
sns.heatmap(numerical.corr(method='spearman'),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Inference:From the above plot we can see there is no co-relation between the numerical variables.

# %%
numerical.corr(method='spearman')*100
# Out:
#                      age        year  gold_medal  silver_medal  brone_medal  \
# age           100.000000   -0.926074   -1.605393     -0.444685    -1.444019
# year           -0.926074  100.000000   -0.274879     -0.229487     0.985895
# gold_medal     -1.605393   -0.274879  100.000000    -40.288958   -45.667885
# silver_medal   -0.444685   -0.229487  -40.288958    100.000000   -47.454781
# brone_medal    -1.444019    0.985895  -45.667885    -47.454781   100.000000
# total_medal    -6.191389    0.582110   24.686954     17.363952     8.421991
#
#               total_medal
# age             -6.191389
# year             0.582110
# gold_medal      24.686954
# silver_medal    17.363952
# brone_medal      8.421991
# total_medal    100.000000

# %% [markdown]
# #### Inference: From the above table we can see that there is no proper co-relation between the numerical variables.

# %%
olympic.groupby('sports')['total_medal'].sum().sort_values(ascending=False).head(10)
# Out:
# sports
# Swimming      765
# Athletics     753
# Rowing        576
# Football      407
# Hockey        387
# Ice Hockey    384
# Handball      351
# Canoeing      333
# Waterpolo     306
# Cycling       306
# Name: total_medal, dtype: int64

# %%
olympic.groupby('sports')['total_medal'].sum().sort_values(ascending=False).head(10).plot(kind='bar').set(ylabel='total medals won',title='Top 10 sports categories with More medals')
# Out:
# [Text(0, 0.5, 'total medals won'),
#  Text(0.5, 1.0, 'Top 10 sports categories with More medals')]

# %% [markdown]
# #### Inference:From the above plot we can see the total no of medals won across each sports

# %%
olympic.groupby('name')['total_medal'].sum().sort_values(ascending=False).head(15)
# Out:
# name
# Michael Phelps             22
# Natalie Coughlin           12
# Ryan Lochte                11
# Leisel Jones                9
# Ole Einar Bjørndalen        9
# Ian Thorpe                  9
# Dara Torres                 8
# Jason Lezak                 8
# Apolo Anton Ohno            8
# Inge de Bruijn              8
# Katalin Kovács              8
# Petria Thomas               7
# Veronica Campbell-Brown     7
# Felix Gottwald              7
# Kati Wilhelm                7
# Name: total_medal, dtype: int64

# %%
olympic.groupby(['name','country'])['total_medal'].sum().sort_values(ascending=False).head(15).plot(ylabel='total medals won',title='Top 15 perons who won more medals form 2000 to 2012',kind='bar')
# Out:
# <AxesSubplot:title={'center':'Top 15 perons who won more medals form 2000 to 2012'}, xlabel='name,country', ylabel='total medals won'>

# %% [markdown]
# #### Inference:From the above bar graph we can  see the people from various countries who won more medals.

# %%
olympic.groupby(['country','sports'])['total_medal'].sum().sort_values(ascending=False).head(20)
# Out:
# country        sports
# United States  Swimming      267
# Australia      Swimming      163
# United States  Athletics     147
# Netherlands    Hockey        113
# United States  Ice Hockey    106
# Canada         Ice Hockey    105
# Russia         Athletics      98
# United States  Basketball     95
# Australia      Hockey         81
# Great Britain  Rowing         80
# Jamaica        Athletics      80
# Cuba           Baseball       72
# Russia         Volleyball     70
# Brazil         Volleyball     70
#                Football       70
# Germany        Canoeing       68
#                Hockey         65
# Argentina      Hockey         64
# Sweden         Ice Hockey     64
# United States  Football       64
# Name: total_medal, dtype: int64

# %% [markdown]
# #### Inference:From the above series  we can see countries , sports and the total medals .

# %%
plt.figure(figsize=(10,5))
olympic.groupby(['country','sports'])['total_medal'].sum().sort_values(ascending=False).head(20).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='country,sports'>

# %% [markdown]
# #### Inference:From the above bar plot we can see the countries  and their sports categories who won more medals.

# %% [markdown]
# #### Conclusion:

# %% [markdown]
# From the above project ,I have treated the missing values values present in the dataset.I also examined the distribution of variables present in the dataset with appropriate variables.Later through visualization, i have identified the group of people and countries who won more medals in olympics.

# %%
import sqlalchemy as sq

# %%
pip install pymysql # installing pymysql package
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/pymysql/

# %%
import pymysql
import pandas as pd

# %%
connect=sq.create_engine("mysql+pymysql://root:Abhinay#2508@localhost/olympic")
df=pd.read_csv(r"C:\Users\dsv24\Downloads\olympic.csv")
df.to_sql('olympics1',connect)

# %% [markdown]
# A connection has been created with mysql and olympics data has been exported there and table is created in the name of "olympics1" in the database "olympics".
